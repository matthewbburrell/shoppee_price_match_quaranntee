# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

path_to_file = 'C:/Users\maxwi/shopee_data/train_images/0000a68812bc7e98c42888dfb1c07da0.jpg'
img = mpimg.imread(path_to_file)

plt.imshow(img)
